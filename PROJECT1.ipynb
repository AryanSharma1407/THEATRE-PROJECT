# %%
#theatre project
nseats = 180
rseats = 20
while True:
    print("***WELCOME TO INOX***")
    name = input("CUSTOMER'S NAME:  ", ).title()
    print ("""WE ARE SERVING TWO TYPE OF SEATS
    1).NORMAL
    2). RECLINER
    PRESS 'normal' for NORMAL SEATS
    PRESS 'recliner' for RECLINER SEATS
    """)
    type = input("TYPE OF SEATS:  ")
    if type == "normal":
        quantity= int(input("HOW MANY SEATS:  " ))
        
        if quantity > nseats:
            print("-"*40)
            print("**SORRY UNAVAILABLE**")
            print (" THANKYOU HAVE A NICE DAY ^-^ ")
            print("-"*40)
            break

        elif quantity <= nseats:
            combo = input("DO YOU WANT TO ADD A COMBO" )
            if combo == "yes":
                print("""****WE HAVE TWO TYPE OF COMBOS***** 
                1). PRESS 1 FOR ADDING A COMBO OF 100
                2). PRESS 2 FOR ADDING A COMBO OF 200""")
                c1 = input(" TYPE OF COMBO")
                if c1 == "1":
                    print("-"*40)
                    print(name)
                    print("YOU ADDED A COMBO OF 100")
                    print (150*quantity+100, " YOUR TOTAL PAYABLE")
                    print (" THANKYOU HAVE A NICE DAY ^-^ ")
                    print("-"*40)
                    break
                elif c1 == "2":
                    print("-"*40)
                    print(name)
                    print("YOU ADDED A COMBO OF 200")
                    print (150*quantity+200, " YOUR TOTAL PAYABLE")
                    print (" THANKYOU HAVE A NICE DAY ^-^ ")
                    nseats -=quantity
                    print("-"*40)
                    break
                
                elif combo == "no":
                    print("-"*40)
                    print(name)
                    print (150*quantity, "YOUR TOTAL PAYABLE")
                    print (" THANKYOU HAVE A NICE DAY ^-^ ")
                    nseats -=quantity
                    print("-"*40)
                    break
               

    
                    
    if type == "recliner":
        quantity= int(input("HOW MANY SEATS"))
        if quantity > rseats:
            print("-"*40)
            print("**SORRY UNAVAILABLE**")
            print (" THANKYOU HAVE A NICE DAY ^-^ ")
            print("-"*40)
            break
        
        elif quantity <= rseats:
            combo = input("DO YOU WANT TO ADD A COMBO" )
            if combo == "yes":
                print("""****WE HAVE TWO TYPE OF COMBOS***** 
    1). PRESS 1 FOR ADDING A COMBO OF 100
                2). PRESS 2 FOR ADDING A COMBO OF 200""")
                c1 = input(" TYPE OF COMBO")
                if c1 == "1":
                    print("-"*40)
                    print(name)
                    print("YOU ADDED A COMBO OF 100")
                    print (200*quantity+100, " YOUR TOTAL PAYABLE")
                    print (" THANKYOU HAVE A NICE DAY ^-^ ")
                    print("-"*40)
                    break

                elif c1 == "2":
                    print("-"*40)
                    print(name)
                    print("YOU ADDED A COMBO OF 200")
                    print (200*quantity+200, " YOUR TOTAL PAYABLE")
                    print (" THANKYOU HAVE A NICE DAY ^-^ ")
                    nseats -=quantity
                    print("-"*40)
                    break
                elif combo == "no":
                    print("-"*40)
                    print(name)
                    print (200*quantity, "YOUR TOTAL PAYABLE")
                    print (" THANKYOU HAVE A NICE DAY ^-^ ")
                    nseats -=quantity
                    print("-"*40)
                    break

repeat = input("REPEAT AGAIN ")
if repeat == "no":
    break
# Out:
# ***WELCOME TO INOX***
